# %%
#!pip install tiktoken

# %%
import tiktoken

# %%
encoding = tiktoken.get_encoding("o200k_base")
encoding
# Out:
# <Encoding 'o200k_base'>

# %%
encoding.encode("黄河之水天上来")
# Out:
# [14495, 21842, 10708, 8936, 867, 4286, 6727]

# %%
len(encoding.encode("黄河之水天上来"))
# Out:
# 7
