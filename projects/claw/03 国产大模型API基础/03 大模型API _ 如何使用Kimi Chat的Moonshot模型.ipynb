# %%
import os
from openai import OpenAI

# %%
client = OpenAI(
    api_key=os.getenv("MOONSHOT_API_KEY"),
    base_url="https://api.moonshot.cn/v1"
)

# %%
response = client.chat.completions.create(
  model="moonshot-v1-8k",
  messages=[
    {"role": "user", "content": "四大文明古国分别有哪些"}
  ]
)
response
# Out:
# ChatCompletion(id='chatcmpl-a3b5d1dd7824441281c341e0766344d4', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='四大文明古国通常指的是以下四个国家：\n\n1. 古埃及文明：位于非洲东北部的尼罗河流域，是最早的文明之一，大约公元前3100年左右开始形成。古埃及文明以其金字塔、法老、象形文字和木乃伊等而闻名于世。\n\n2. 古巴比伦文明：位于亚洲西部的两河流域，即底格里斯河和幼发拉底河流域。古巴比伦文明大约公元前3500年左右开始形成，以其《汉谟拉比法典》、空中花园和巴比伦塔等而著称。\n\n3. 古印度文明：位于南亚的印度次大陆，主要分布在印度河流域。古印度文明大约公元前2600年左右开始形成，以其佛教、印度教、梵文和阿育王等而闻名。\n\n4. 古中国文明：位于东亚的黄河流域，是中华文明的发源地。古中国文明大约公元前2100年左右开始形成，以其长城、兵马俑、甲骨文、四大发明等而著称。\n\n这四个文明古国在人类历史上具有重要地位，它们的发展和影响对后世产生了深远的影响。', role='assistant', function_call=None, tool_calls=None))], created=1723775748, model='moonshot-v1-8k', object='chat.completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=245, prompt_tokens=14, total_tokens=259))

# %%
print(response.choices[0].message.content)
# Out:
# 四大文明古国通常指的是以下四个国家：
#
# 1. 古埃及文明：位于非洲东北部的尼罗河流域，是最早的文明之一，大约公元前3100年左右开始形成。古埃及文明以其金字塔、法老、象形文字和木乃伊等而闻名于世。
#
# 2. 古巴比伦文明：位于亚洲西部的两河流域，即底格里斯河和幼发拉底河流域。古巴比伦文明大约公元前3500年左右开始形成，以其《汉谟拉比法典》、空中花园和巴比伦塔等而著称。
#
# 3. 古印度文明：位于南亚的印度次大陆，主要分布在印度河流域。古印度文明大约公元前2600年左右开始形成，以其佛教、印度教、梵文和阿育王等而闻名。
#
# 4. 古中国文明：位于东亚的黄河流域，是中华文明的发源地。古中国文明大约公元前2100年左右开始形成，以其长城、兵马俑、甲骨文、四大发明等而著称。
#
# 这四个文明古国在人类历史上具有重要地位，它们的发展和影响对后世产生了深远的影响。
