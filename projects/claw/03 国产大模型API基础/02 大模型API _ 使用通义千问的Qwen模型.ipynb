# %%
import os
from openai import OpenAI

# %%
client = OpenAI(
    api_key=os.getenv("DASHSCOPE_API_KEY"),
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1",
)

# %%
response = client.chat.completions.create(
  model="qwen-plus",
  messages=[
    {"role": "user", "content": "四大文明古国分别有哪些"}
  ]
)
response
# Out:
# ChatCompletion(id='chatcmpl-5812921e-d38f-9854-a3fb-ebd9b1f51c61', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='四大文明古国分别是：古埃及、古印度、古巴比伦和古代中国。\n\n1. **古埃及**：位于非洲东北部，尼罗河贯穿埃及南北，为古埃及人提供了良好的农业条件。古埃及文明以其宏伟的金字塔建筑和复杂的象形文字而闻名。\n\n2. **古印度**：主要分布在今天的印度河流域，包括今天的巴基斯坦和印度西北部地区。古印度文明以哈拉帕和摩亨佐-达罗等城市为代表，以其高度发达的城市规划和排水系统著称。\n\n3. **古巴比伦**：位于今天的伊拉克一带，美索不达米亚平原上。古巴比伦文明以汉谟拉比法典和巴别塔而闻名于世，展现了其在法律和社会管理方面的先进性。\n\n4. **古代中国**：主要分布在黄河流域和长江流域。中国古代文明以其悠久的历史、独特的文字体系（甲骨文、金文等）、发达的农业技术和哲学思想而著称。\n\n这四个文明都是在大约公元前3500年至前3000年之间形成，并在随后的几千年里对世界文化产生了深远影响。', role='assistant', function_call=None, tool_calls=None))], created=1723737656, model='qwen-plus', object='chat.completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=246, prompt_tokens=14, total_tokens=260))

# %%
print(response.choices[0].message.content)
# Out:
# 四大文明古国分别是：古埃及、古印度、古巴比伦和古代中国。
#
# 1. **古埃及**：位于非洲东北部，尼罗河贯穿埃及南北，为古埃及人提供了良好的农业条件。古埃及文明以其宏伟的金字塔建筑和复杂的象形文字而闻名。
#
# 2. **古印度**：主要分布在今天的印度河流域，包括今天的巴基斯坦和印度西北部地区。古印度文明以哈拉帕和摩亨佐-达罗等城市为代表，以其高度发达的城市规划和排水系统著称。
#
# 3. **古巴比伦**：位于今天的伊拉克一带，美索不达米亚平原上。古巴比伦文明以汉谟拉比法典和巴别塔而闻名于世，展现了其在法律和社会管理方面的先进性。
#
# 4. **古代中国**：主要分布在黄河流域和长江流域。中国古代文明以其悠久的历史、独特的文字体系（甲骨文、金文等）、发达的农业技术和哲学思想而著称。
#
# 这四个文明都是在大约公元前3500年至前3000年之间形成，并在随后的几千年里对世界文化产生了深远影响。
