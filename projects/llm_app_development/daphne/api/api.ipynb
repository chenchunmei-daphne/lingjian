# %%
import os
from openai import OpenAI
api_key = os.getenv("qianwen_openai_api")
client = OpenAI(api_key=api_key,
base_url="https://ws-s6eavmbn4d8prjq0.cn-beijing.maas.aliyuncs.com/compatible-mode/v1",)
# "https://api.qianwen.aliyun.com/v1"
messages = [{"role":"user", "content":"你是谁"}]
completion = client.chat.completions.create(
    model="qwen-turbo",
    messages=messages,
    n=len(messages),)


for i, choice in enumerate(completion.choices):
    print(f"回答 {i+1}: {choice.message.content}\n")

print(completion.choices[0].message.content)
print(completion.choices)
# Out:
# 回答 1: 我是通义千问，是阿里巴巴集团旗下的通义实验室自主研发的超大规模语言模型。我能够回答问题、创作文字、逻辑推理、编程等多种任务。你可以问我任何问题，我会尽我所能提供帮助。
#
# 我是通义千问，是阿里巴巴集团旗下的通义实验室自主研发的超大规模语言模型。我能够回答问题、创作文字、逻辑推理、编程等多种任务。你可以问我任何问题，我会尽我所能提供帮助。
# [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='我是通义千问，是阿里巴巴集团旗下的通义实验室自主研发的超大规模语言模型。我能够回答问题、创作文字、逻辑推理、编程等多种任务。你可以问我任何问题，我会尽我所能提供帮助。', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None))]

# %%
print(completion.choices[0])
# Out:
# Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='我是通义千问，是阿里巴巴集团旗下的通义实验室自主研发的超大规模语言模型。我能够回答问题、创作文字、逻辑推理、编程等多种任务。你可以问我任何问题，我会尽我所能提供帮助。', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None))

# %% [markdown]
# 参数
# max_tokens:
# temperature: 越大随机越大，默认值为 1， 范围[0,1]
# top_p:
# frequency_penalty: [-2, 2]
# presence_penalty:
#
# ! openai_api游乐园：https://platform.openai.com/playground
#
# json数据格式
